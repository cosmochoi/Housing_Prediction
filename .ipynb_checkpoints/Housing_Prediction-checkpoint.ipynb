# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
trainset = pd.read_csv('./dataset/train.csv')
testset = pd.read_csv('./dataset/test.csv')
trainset = trainset[trainset.GrLivArea < 4000]
testset = testset[testset.GrLivArea < 4000]
y_train = trainset.SalePrice.values
trainset.columns
pd.set_option('display.max_columns', 999)

# %%
ntrain = trainset.shape[0]
ntest = testset.shape[0]

all_data = pd.concat((trainset, testset)).reset_index(drop=True)
all_data.drop(['SalePrice'], axis=1, inplace=True)

# %%
print(y_train)
# Out:
# [208500 181500 223500 ... 266500 142125 147500]

# %%
# General Look at SalePrice
trainset['SalePrice'].plot.hist()
plt.xlabel('Price in $')
plt.title('Sales Price of Houses in Training Set')

trainset['SalePrice'].describe() # Taking a look at the distribution
# Out:
# count      1456.000000
# mean     180151.233516
# std       76696.592530
# min       34900.000000
# 25%      129900.000000
# 50%      163000.000000
# 75%      214000.000000
# max      625000.000000
# Name: SalePrice, dtype: float64

# %%
plt.hist(y)
plt.xlabel('Log transformed Price')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-e32a7df8d4be> in <module>
# ----> 1 plt.hist(y)
#       2 plt.xlabel('Log transformed Price')
#
# NameError: name 'y' is not defined

# %%
fig = plt.figure(figsize=(20,9))
ax = fig.gca()
all_data.hist(ax = ax)
# Out:
# /home/annie/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   This is separate from the ipykernel package so we can avoid doing imports until
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2bbfb810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2ba5ee50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2ba18690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b9cae90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b9fea90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b9b9e10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b96dad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b928310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b928e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b8e4810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b84fb50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b80fed0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b7c5b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b787f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b7bbbd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b77df50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b730c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b6f1f90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b6a6c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b665fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b61cc90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b5db4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b592cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b551510>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b506d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b4c5550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2bb9fc90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2bc20a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b4f6dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b4aba90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b46ce10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b425ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b3e3e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b399b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b359e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b30fb50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b2cded0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b283b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b245f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b279bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b239f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcf2b1eec10>]],
#       dtype=object)

# %%
all_data[all_data.isnull().any(axis=1)] 
nullnum = {}
percentage = {}
for element in all_data.columns:
    nullnum[element] = all_data[element].isna().sum()
    percentage[element] = all_data[element].isna().sum()/all_data[[element]].shape[0] * 100

pd.DataFrame(sorted(percentage.items(), key=lambda x: x[1], reverse=True), columns = ['Feature', '% NA'])
sorted(percentage.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('PoolQC', 99.7254632807138),
#  ('MiscFeature', 96.39670555936857),
#  ('Alley', 93.20521619766645),
#  ('Fence', 80.43925875085792),
#  ('FireplaceQu', 48.730267673301306),
#  ('LotFrontage', 16.678105696636926),
#  ('GarageYrBlt', 5.456417295813315),
#  ('GarageFinish', 5.456417295813315),
#  ('GarageQual', 5.456417295813315),
#  ('GarageCond', 5.456417295813315),
#  ('GarageType', 5.3877831159917635),
#  ('BsmtCond', 2.8140013726835966),
#  ('BsmtExposure', 2.8140013726835966),
#  ('BsmtQual', 2.7796842827728208),
#  ('BsmtFinType2', 2.7453671928620453),
#  ('BsmtFinType1', 2.7110501029512695),
#  ('MasVnrType', 0.8236101578586137),
#  ('MasVnrArea', 0.789293067947838),
#  ('MSZoning', 0.13726835964310227),
#  ('Utilities', 0.06863417982155114),
#  ('BsmtFullBath', 0.06863417982155114),
#  ('BsmtHalfBath', 0.06863417982155114),
#  ('Functional', 0.06863417982155114),
#  ('Exterior1st', 0.03431708991077557),
#  ('Exterior2nd', 0.03431708991077557),
#  ('BsmtFinSF1', 0.03431708991077557),
#  ('BsmtFinSF2', 0.03431708991077557),
#  ('BsmtUnfSF', 0.03431708991077557),
#  ('TotalBsmtSF', 0.03431708991077557),
#  ('Electrical', 0.03431708991077557),
#  ('KitchenQual', 0.03431708991077557),
#  ('GarageCars', 0.03431708991077557),
#  ('GarageArea', 0.03431708991077557),
#  ('SaleType', 0.03431708991077557),
#  ('Id', 0.0),
#  ('MSSubClass', 0.0),
#  ('LotArea', 0.0),
#  ('Street', 0.0),
#  ('LotShape', 0.0),
#  ('LandContour', 0.0),
#  ('LotConfig', 0.0),
#  ('LandSlope', 0.0),
#  ('Neighborhood', 0.0),
#  ('Condition1', 0.0),
#  ('Condition2', 0.0),
#  ('BldgType', 0.0),
#  ('HouseStyle', 0.0),
#  ('OverallQual', 0.0),
#  ('OverallCond', 0.0),
#  ('YearBuilt', 0.0),
#  ('YearRemodAdd', 0.0),
#  ('RoofStyle', 0.0),
#  ('RoofMatl', 0.0),
#  ('ExterQual', 0.0),
#  ('ExterCond', 0.0),
#  ('Foundation', 0.0),
#  ('Heating', 0.0),
#  ('HeatingQC', 0.0),
#  ('CentralAir', 0.0),
#  ('1stFlrSF', 0.0),
#  ('2ndFlrSF', 0.0),
#  ('LowQualFinSF', 0.0),
#  ('GrLivArea', 0.0),
#  ('FullBath', 0.0),
#  ('HalfBath', 0.0),
#  ('BedroomAbvGr', 0.0),
#  ('KitchenAbvGr', 0.0),
#  ('TotRmsAbvGrd', 0.0),
#  ('Fireplaces', 0.0),
#  ('PavedDrive', 0.0),
#  ('WoodDeckSF', 0.0),
#  ('OpenPorchSF', 0.0),
#  ('EnclosedPorch', 0.0),
#  ('3SsnPorch', 0.0),
#  ('ScreenPorch', 0.0),
#  ('PoolArea', 0.0),
#  ('MiscVal', 0.0),
#  ('MoSold', 0.0),
#  ('YrSold', 0.0),
#  ('SaleCondition', 0.0)]

# %%
#Some of the columns look like they're mostly Na values. 
# Let's remove the four columns that are mostly na values
remove = ['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'Id']
all_data.drop(remove, axis = 1, inplace = True)

# %%
#trainset.columns[trainset.isnull().any(axis=0)] 

#LotFrontage Imputation
all_data[all_data['LotFrontage'].isna()]
print('LotFrontage mean is: %.2f' %all_data['LotFrontage'].mean())
all_data['LotFrontage'].plot(kind = 'hist')
# Since the mean 69.31 seems to match well with the histogram, we can impute the missing values with the mean
all_data['LotFrontage'] = all_data['LotFrontage'].fillna(all_data['LotFrontage'].mean())
# Out:
# LotFrontage mean is: 69.10

# %%
# MasVnrType imputation
all_data[all_data['MasVnrType'].isna()]
all_data['MasVnrType'].value_counts()
# Out:
# None       1741
# BrkFace     878
# Stone       246
# BrkCmn       25
# Name: MasVnrType, dtype: int64

# %%
pd.DataFrame(all_data['MasVnrType'].value_counts()).plot(kind = 'bar')
all_data['MasVnrType'] = all_data['MasVnrType'].fillna('None')

# %%
all_data[all_data['MasVnrArea'].isna()]
print('Masonry veneer area mean is: %.2f' %all_data['MasVnrArea'].mean())
# None values of the Masonry veneer means there is no masonry veneer, so we will impute these values as 0
all_data['MasVnrArea'] = all_data['MasVnrArea'].fillna(0)
all_data['MasVnrArea'].plot(kind = 'hist')
# Out:
# Masonry veneer area mean is: 101.01

# %%
print(all_data.columns[all_data.isnull().any(axis=0)])
#Na for Basement quality refers to no basement, so we shouldn't impute / 37 no basements 
all_data['BsmtQual'].isna().sum()
all_data['BsmtQual'] = all_data['BsmtQual'].fillna('None')
all_data['BsmtCond'].isna().sum() # impute 'None' for basements with no basements!
all_data['BsmtCond'] = all_data['BsmtCond'].fillna('None')
pd.DataFrame(all_data['BsmtCond'].value_counts()).plot(kind = 'bar')
# Out:
# Index(['MSZoning', 'Utilities', 'Exterior1st', 'Exterior2nd', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Electrical',
#        'BsmtFullBath', 'BsmtHalfBath', 'KitchenQual', 'Functional',
#        'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish',
#        'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'SaleType'],
#       dtype='object')

# %%
# Impute Basement Variables
all_data['BsmtExposure'] = all_data['BsmtExposure'].fillna('None')
all_data['BsmtFinType1'] = all_data['BsmtFinType1'].fillna('None')
all_data['BsmtFinType2'] = all_data['BsmtFinType2'].fillna('None')

# %%
#Impute Electrical NA
all_data[all_data['Electrical'].isna()] # Assume standard circuit for the na for electric
all_data['Electrical'] = all_data['Electrical'].fillna('SBrkr')
pd.DataFrame(all_data['Electrical'].value_counts()).plot(kind = 'bar')

# %%
# Impute Fireplace Quality NA
print(all_data.columns[all_data.isnull().any(axis=0)])
all_data[all_data['FireplaceQu'].isna()]
#Fireplace Quality is na because there are no fireplaces for these houses
all_data['FireplaceQu'] = all_data['FireplaceQu'].fillna('None')
# Out:
# Index(['MSZoning', 'Utilities', 'Exterior1st', 'Exterior2nd', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath',
#        'BsmtHalfBath', 'KitchenQual', 'Functional', 'FireplaceQu',
#        'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea',
#        'GarageQual', 'GarageCond', 'SaleType'],
#       dtype='object')

# %%
print(all_data.columns[all_data.isnull().any(axis=0)])
all_data['GarageType'] = all_data['GarageType'].fillna('None')
all_data['GarageYrBlt'] = all_data['GarageYrBlt'].fillna(0)
all_data['GarageFinish'] = all_data['GarageFinish'].fillna('None')
all_data['GarageQual'] = all_data['GarageQual'].fillna('None')
all_data['GarageCond'] = all_data['GarageCond'].fillna('None')
all_data['GarageCars'] = all_data['GarageCars'].fillna(0)
all_data['GarageArea'] = all_data['GarageArea'].fillna(0)
# Out:
# Index(['MSZoning', 'Utilities', 'Exterior1st', 'Exterior2nd', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath',
#        'BsmtHalfBath', 'KitchenQual', 'Functional', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'SaleType'],
#       dtype='object')

# %%
print(all_data.columns[all_data.isnull().any(axis=0)])
# Out:
# Index(['MSZoning', 'Utilities', 'Exterior1st', 'Exterior2nd', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath',
#        'BsmtHalfBath', 'KitchenQual', 'Functional', 'SaleType'],
#       dtype='object')

# %%
#MSZoning imputation
all_data[all_data['MSZoning'].isna()] # Assume standard circuit for the na for electric
all_data['MSZoning'] = all_data['MSZoning'].fillna(all_data['MSZoning'].mode()[0])
pd.DataFrame(all_data['MSZoning'].value_counts()).plot(kind = 'bar')

# %%
#BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath','BsmtHalfBath',BsmtFinSF1 imputation
all_data[all_data['BsmtUnfSF'].isna()]
all_data['BsmtUnfSF'] = all_data['BsmtUnfSF'].fillna(0)
all_data['BsmtFinSF2'] = all_data['BsmtFinSF2'].fillna(0)
all_data['BsmtFinSF1'] = all_data['BsmtFinSF1'].fillna(0)
all_data['TotalBsmtSF'] = all_data['TotalBsmtSF'].fillna(0)
all_data['BsmtFullBath'] = all_data['BsmtFullBath'].fillna(0)
all_data['BsmtHalfBath'] = all_data['BsmtHalfBath'].fillna(0)

# %%
all_data['Utilities'].value_counts()
#all_data[all_data['Utilities'].isna()]
#There is only 2 NAs, this seems like random, and unrelated. In fact, all utilities are 'AllPub' except for one. We will delete this feature/
all_data.drop(['Utilities'], axis = 1, inplace=True)

# %%
all_data['Exterior1st'].value_counts() # we can't just delete these values, since there is no discernable pattern
# We will imput the NAs with the mode.
all_data['Exterior1st'] = all_data['Exterior1st'].fillna(all_data['Exterior1st'].mode()[0])
all_data['Exterior2nd'] = all_data['Exterior2nd'].fillna(all_data['Exterior2nd'].mode()[0])

# %%
all_data['KitchenQual'].value_counts() # again, impute with the node, as 'Typical'
all_data['KitchenQual'] = all_data['KitchenQual'].fillna(all_data['KitchenQual'].mode()[0])

# %%
all_data['Functional'].value_counts() # Impute missing values with typical, the mode.
all_data['Functional'] = all_data['Functional'].fillna(all_data['Functional'].mode()[0])

# %%
all_data['SaleType'].value_counts() # No other information on missing values, and no particular pattern. Impute with mode. 
all_data['SaleType'] = all_data['SaleType'].fillna(all_data['SaleType'].mode()[0])

# %%
all_data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          60       RL         65.0     8450   Pave      Reg         Lvl
# 1          20       RL         80.0     9600   Pave      Reg         Lvl
# 2          60       RL         68.0    11250   Pave      IR1         Lvl
# 3          70       RL         60.0     9550   Pave      IR1         Lvl
# 4          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 0    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 1       FR2       Gtl      Veenker      Feedr       Norm     1Fam     1Story
# 2    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 3    Corner       Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 4       FR2       Gtl      NoRidge       Norm       Norm     1Fam     2Story
#
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl  \
# 0            7            5       2003          2003     Gable  CompShg
# 1            6            8       1976          1976     Gable  CompShg
# 2            7            5       2001          2002     Gable  CompShg
# 3            7            5       1915          1970     Gable  CompShg
# 4            8            5       2000          2000     Gable  CompShg
#
#   Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond  \
# 0     VinylSd     VinylSd    BrkFace       196.0        Gd        TA
# 1     MetalSd     MetalSd       None         0.0        TA        TA
# 2     VinylSd     VinylSd    BrkFace       162.0        Gd        TA
# 3     Wd Sdng     Wd Shng       None         0.0        TA        TA
# 4     VinylSd     VinylSd    BrkFace       350.0        Gd        TA
#
#   Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1  \
# 0      PConc       Gd       TA           No          GLQ       706.0
# 1     CBlock       Gd       TA           Gd          ALQ       978.0
# 2      PConc       Gd       TA           Mn          GLQ       486.0
# 3     BrkTil       TA       Gd           No          ALQ       216.0
# 4      PConc       Gd       TA           Av          GLQ       655.0
#
#   BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC  \
# 0          Unf         0.0      150.0        856.0    GasA        Ex
# 1          Unf         0.0      284.0       1262.0    GasA        Ex
# 2          Unf         0.0      434.0        920.0    GasA        Ex
# 3          Unf         0.0      540.0        756.0    GasA        Gd
# 4          Unf         0.0      490.0       1145.0    GasA        Ex
#
#   CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  \
# 0          Y      SBrkr       856       854             0       1710
# 1          Y      SBrkr      1262         0             0       1262
# 2          Y      SBrkr       920       866             0       1786
# 3          Y      SBrkr       961       756             0       1717
# 4          Y      SBrkr      1145      1053             0       2198
#
#    BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 0           1.0           0.0         2         1             3             1
# 1           0.0           1.0         2         0             3             1
# 2           1.0           0.0         2         1             3             1
# 3           1.0           0.0         1         0             3             1
# 4           1.0           0.0         2         1             4             1
#
#   KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  \
# 0          Gd             8        Typ           0        None     Attchd
# 1          TA             6        Typ           1          TA     Attchd
# 2          Gd             6        Typ           1          TA     Attchd
# 3          Gd             7        Typ           1          Gd     Detchd
# 4          Gd             9        Typ           1          TA     Attchd
#
#    GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond  \
# 0       2003.0          RFn         2.0       548.0         TA         TA
# 1       1976.0          RFn         2.0       460.0         TA         TA
# 2       2001.0          RFn         2.0       608.0         TA         TA
# 3       1998.0          Unf         3.0       642.0         TA         TA
# 4       2000.0          RFn         3.0       836.0         TA         TA
#
#   PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0          Y           0           61              0          0            0
# 1          Y         298            0              0          0            0
# 2          Y           0           42              0          0            0
# 3          Y           0           35            272          0            0
# 4          Y         192           84              0          0            0
#
#    PoolArea  MiscVal  MoSold  YrSold SaleType SaleCondition
# 0         0        0       2    2008       WD        Normal
# 1         0        0       5    2007       WD        Normal
# 2         0        0       9    2008       WD        Normal
# 3         0        0       2    2006       WD       Abnorml
# 4         0        0      12    2008       WD        Normal

# %% [markdown]
# ## Categorical Features and Dummifying

# %%
print(all_data.info())
data_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2914 entries, 0 to 2913
# Data columns (total 74 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2914 non-null   int64
#  1   MSZoning       2914 non-null   object
#  2   LotFrontage    2914 non-null   float64
#  3   LotArea        2914 non-null   int64
#  4   Street         2914 non-null   object
#  5   LotShape       2914 non-null   object
#  6   LandContour    2914 non-null   object
#  7   LotConfig      2914 non-null   object
#  8   LandSlope      2914 non-null   object
#  9   Neighborhood   2914 non-null   object
#  10  Condition1     2914 non-null   object
#  11  Condition2     2914 non-null   object
#  12  BldgType       2914 non-null   object
#  13  HouseStyle     2914 non-null   object
#  14  OverallQual    2914 non-null   int64
#  15  OverallCond    2914 non-null   int64
#  16  YearBuilt      2914 non-null   int64
#  17  YearRemodAdd   2914 non-null   int64
#  18  RoofStyle      2914 non-null   object
#  19  RoofMatl       2914 non-null   object
#  20  Exterior1st    2914 non-null   object
#  21  Exterior2nd    2914 non-null   object
#  22  MasVnrType     2914 non-null   object
#  23  MasVnrArea     2914 non-null   float64
#  24  ExterQual      2914 non-null   object
#  25  ExterCond      2914 non-null   object
#  26  Foundation     2914 non-null   object
#  27  BsmtQual       2914 non-null   object
#  28  BsmtCond       2914 non-null   object
#  29  BsmtExposure   2914 non-null   object
#  30  BsmtFinType1   2914 non-null   object
#  31  BsmtFinSF1     2914 non-null   float64
#  32  BsmtFinType2   2914 non-null   object
#  33  BsmtFinSF2     2914 non-null   float64
#  34  BsmtUnfSF      2914 non-null   float64
#  35  TotalBsmtSF    2914 non-null   float64
#  36  Heating        2914 non-null   object
#  37  HeatingQC      2914 non-null   object
#  38  CentralAir     2914 non-null   object
#  39  Electrical     2914 non-null   object
#  40  1stFlrSF       2914 non-null   int64
#  41  2ndFlrSF       2914 non-null   int64
#  42  LowQualFinSF   2914 non-null   int64
#  43  GrLivArea      2914 non-null   int64
#  44  BsmtFullBath   2914 non-null   float64
#  45  BsmtHalfBath   2914 non-null   float64
#  46  FullBath       2914 non-null   int64
#  47  HalfBath       2914 non-null   int64
#  48  BedroomAbvGr   2914 non-null   int64
#  49  KitchenAbvGr   2914 non-null   int64
#  50  KitchenQual    2914 non-null   object
#  51  TotRmsAbvGrd   2914 non-null   int64
#  52  Functional     2914 non-null   object
#  53  Fireplaces     2914 non-null   int64
#  54  FireplaceQu    2914 non-null   object
#  55  GarageType     2914 non-null   object
#  56  GarageYrBlt    2914 non-null   float64
#  57  GarageFinish   2914 non-null   object
#  58  GarageCars     2914 non-null   float64
#  59  GarageArea     2914 non-null   float64
#  60  GarageQual     2914 non-null   object
#  61  GarageCond     2914 non-null   object
#  62  PavedDrive     2914 non-null   object
#  63  WoodDeckSF     2914 non-null   int64
#  64  OpenPorchSF    2914 non-null   int64
#  65  EnclosedPorch  2914 non-null   int64
#  66  3SsnPorch      2914 non-null   int64
#  67  ScreenPorch    2914 non-null   int64
#  68  PoolArea       2914 non-null   int64
#  69  MiscVal        2914 non-null   int64
#  70  MoSold         2914 non-null   int64
#  71  YrSold         2914 non-null   int64
#  72  SaleType       2914 non-null   object
#  73  SaleCondition  2914 non-null   object
# dtypes: float64(11), int64(25), object(38)
# memory usage: 1.6+ MB
# None
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-b530b7f03a34> in <module>
#       1 print(all_data.info())
# ----> 2 data_cat.info()
#
# NameError: name 'data_cat' is not defined

# %% [markdown]
# ### Dividing into Binary/Non-binary Nominal/Ordinal categorical features

# %%
data_cat = all_data.select_dtypes(include=['object']).copy()
data_cat.head()
nominal = ['MSZoning', 'Street', 'LandContour', 'LotConfig', 'Neighborhood', 'Condition1', 'Condition2', 'RoofStyle',
          'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'Foundation','Heating', 'CentralAir', 'Electrical', 
           'GarageType', 'GarageFinish', 'PavedDrive', 'SaleType']
ordinal = ['LotShape', 'LandSlope', 'BldgType', 'HouseStyle', 'ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond', 'BmstExposure', 
          'BsmtFinType1', 'BsmtFinType2','HeatingQC', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageQual', 'GarageCond', 'SaleCondition']

# %%
data_cat.head()
# Out:
#   MSZoning Street LotShape LandContour LotConfig LandSlope Neighborhood  \
# 0       RL   Pave      Reg         Lvl    Inside       Gtl      CollgCr
# 1       RL   Pave      Reg         Lvl       FR2       Gtl      Veenker
# 2       RL   Pave      IR1         Lvl    Inside       Gtl      CollgCr
# 3       RL   Pave      IR1         Lvl    Corner       Gtl      Crawfor
# 4       RL   Pave      IR1         Lvl       FR2       Gtl      NoRidge
#
#   Condition1 Condition2 BldgType HouseStyle RoofStyle RoofMatl Exterior1st  \
# 0       Norm       Norm     1Fam     2Story     Gable  CompShg     VinylSd
# 1      Feedr       Norm     1Fam     1Story     Gable  CompShg     MetalSd
# 2       Norm       Norm     1Fam     2Story     Gable  CompShg     VinylSd
# 3       Norm       Norm     1Fam     2Story     Gable  CompShg     Wd Sdng
# 4       Norm       Norm     1Fam     2Story     Gable  CompShg     VinylSd
#
#   Exterior2nd MasVnrType ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 0     VinylSd    BrkFace        Gd        TA      PConc       Gd       TA
# 1     MetalSd       None        TA        TA     CBlock       Gd       TA
# 2     VinylSd    BrkFace        Gd        TA      PConc       Gd       TA
# 3     Wd Shng       None        TA        TA     BrkTil       TA       Gd
# 4     VinylSd    BrkFace        Gd        TA      PConc       Gd       TA
#
#   BsmtExposure BsmtFinType1 BsmtFinType2 Heating HeatingQC CentralAir  \
# 0           No          GLQ          Unf    GasA        Ex          Y
# 1           Gd          ALQ          Unf    GasA        Ex          Y
# 2           Mn          GLQ          Unf    GasA        Ex          Y
# 3           No          ALQ          Unf    GasA        Gd          Y
# 4           Av          GLQ          Unf    GasA        Ex          Y
#
#   Electrical KitchenQual Functional FireplaceQu GarageType GarageFinish  \
# 0      SBrkr          Gd        Typ        None     Attchd          RFn
# 1      SBrkr          TA        Typ          TA     Attchd          RFn
# 2      SBrkr          Gd        Typ          TA     Attchd          RFn
# 3      SBrkr          Gd        Typ          Gd     Detchd          Unf
# 4      SBrkr          Gd        Typ          TA     Attchd          RFn
#
#   GarageQual GarageCond PavedDrive SaleType SaleCondition
# 0         TA         TA          Y       WD        Normal
# 1         TA         TA          Y       WD        Normal
# 2         TA         TA          Y       WD        Normal
# 3         TA         TA          Y       WD       Abnorml
# 4         TA         TA          Y       WD        Normal

# %%
#Binary categorical features
all_data["CentralAir"] = np.where(all_data["CentralAir"].str.contains("Y"), 1, 0)

# %%
all_data["PavedDrive"] = np.where(all_data["PavedDrive"].str.contains("Y"), 1, 0)

# %%
# Label Encode nominal categorical values 
from sklearn.preprocessing import LabelEncoder

lb_make = LabelEncoder()
for column in nominal:
    all_data[column] = lb_make.fit_transform(all_data[column])
all_data.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street LotShape  LandContour  \
# 0          60         3         65.0     8450       1      Reg            3
# 1          20         3         80.0     9600       1      Reg            3
# 2          60         3         68.0    11250       1      IR1            3
# 3          70         3         60.0     9550       1      IR1            3
# 4          60         3         84.0    14260       1      IR1            3
#
#    LotConfig LandSlope  Neighborhood  Condition1  Condition2 BldgType  \
# 0          4       Gtl             5           2           2     1Fam
# 1          2       Gtl            24           1           2     1Fam
# 2          4       Gtl             5           2           2     1Fam
# 3          0       Gtl             6           2           2     1Fam
# 4          2       Gtl            15           2           2     1Fam
#
#   HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd  RoofStyle  \
# 0     2Story            7            5       2003          2003          1
# 1     1Story            6            8       1976          1976          1
# 2     2Story            7            5       2001          2002          1
# 3     2Story            7            5       1915          1970          1
# 4     2Story            8            5       2000          2000          1
#
#    RoofMatl  Exterior1st  Exterior2nd  MasVnrType  MasVnrArea ExterQual  \
# 0         0           12           13           1       196.0        Gd
# 1         0            8            8           2         0.0        TA
# 2         0           12           13           1       162.0        Gd
# 3         0           13           15           2         0.0        TA
# 4         0           12           13           1       350.0        Gd
#
#   ExterCond  Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 0        TA           2       Gd       TA           No          GLQ
# 1        TA           1       Gd       TA           Gd          ALQ
# 2        TA           2       Gd       TA           Mn          GLQ
# 3        TA           0       TA       Gd           No          ALQ
# 4        TA           2       Gd       TA           Av          GLQ
#
#    BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  Heating  \
# 0       706.0          Unf         0.0      150.0        856.0        1
# 1       978.0          Unf         0.0      284.0       1262.0        1
# 2       486.0          Unf         0.0      434.0        920.0        1
# 3       216.0          Unf         0.0      540.0        756.0        1
# 4       655.0          Unf         0.0      490.0       1145.0        1
#
#   HeatingQC  CentralAir  Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0        Ex           1           4       856       854             0
# 1        Ex           1           4      1262         0             0
# 2        Ex           1           4       920       866             0
# 3        Gd           1           4       961       756             0
# 4        Ex           1           4      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710           1.0           0.0         2         1             3
# 1       1262           0.0           1.0         2         0             3
# 2       1786           1.0           0.0         2         1             3
# 3       1717           1.0           0.0         1         0             3
# 4       2198           1.0           0.0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0        None
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#    GarageType  GarageYrBlt  GarageFinish  GarageCars  GarageArea GarageQual  \
# 0           1       2003.0             2         2.0       548.0         TA
# 1           1       1976.0             2         2.0       460.0         TA
# 2           1       2001.0             2         2.0       608.0         TA
# 3           5       1998.0             3         3.0       642.0         TA
# 4           1       2000.0             2         3.0       836.0         TA
#
#   GarageCond  PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA           1           0           61              0          0
# 1         TA           1         298            0              0          0
# 2         TA           1           0           42              0          0
# 3         TA           1           0           35            272          0
# 4         TA           1         192           84              0          0
#
#    ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  SaleType SaleCondition
# 0            0         0        0       2    2008         8        Normal
# 1            0         0        0       5    2007         8        Normal
# 2            0         0        0       9    2008         8        Normal
# 3            0         0        0       2    2006         8       Abnorml
# 4            0         0        0      12    2008         8        Normal

# %%
# Encoding Ordinal categorical values
ordinal
ordinalEncode = {"LotShape": {"Reg": 0, "IR1": 1,
                                 "IR2": 2, "IR3": 3},
                "LandSlope": {"Gtl": 0, "Mod": 1, "Sev": 2},
                "BldgType": {"TwnhsI":1, "TwnhsE":1, "Twnhs":1, "Duplx":2, "Duplex":2, "2FmCon":3, "2fmCon":3, "1Fam": 4},
                "HouseStyle": {"1Story": 1, "1.5Fin": 3, "1.5Unf": 2,
                              "2Story": 3, "2.5Fin": 5, "2.5Unf": 4,
                              "SFoyer": 6, "SLvl": 7},
                 "HeatingQC": {"Po":1, "Fa":2, "TA":3, "Gd":4, "Ex":5},
                 "ExterQual": {"Po": 1, "Fa": 2, "TA": 3, "Gd": 4, "Ex": 5},
                 "ExterCond": {"Po": 1, "Fa": 2, "TA": 3, "Gd": 4, "Ex": 5},
                 "BsmtQual": {"None": 0, "Po": 1, "Fa": 2, "TA": 3, "Gd": 4, "Ex": 5},
                 "BsmtCond": {"None": 0, "Po": 1, "Fa": 2, "TA": 3, "Gd": 4, "Ex": 5},
                 "BsmtExposure": {"None":0, "No":1, "Mn": 2, "Av": 3, "Gd":4},
                 "BsmtFinType1": {"None":0, "Unf":1, "LwQ": 2, "Rec": 3, "BLQ": 4, "ALQ":5, "GLQ":6},
                 "BsmtFinType2": {"None":0, "Unf":1, "LwQ": 2, "Rec": 3, "BLQ": 4, "ALQ":5, "GLQ":6},
                 "KitchenQual": {"Po": 1, "Fa": 2, "TA": 3, "Gd":4, "Ex":5},
                 "Functional": {"Sal":0, "Sev":1, "Maj2":2, "Maj1":3, "Mod": 4, "Min2": 5, "Min1":6, "Typ":7},
                 "FireplaceQu": {"None":0, "Po":1, "Fa":2, "TA":3, "Gd":4, "Ex":5},
                 "GarageQual": {"None":0, "Po":1, "Fa":2, "TA":3, "Gd":4, "Ex":5},
                 "GarageCond": {"None":0, "Po":1, "Fa":2, "TA":3, "Gd":4, "Ex":5},
                 "SaleCondition": {"Partial":0, "Family":1, "Alloca":2, "AdjLand":3, "Abnorml":4, "Normal":5} 
                }

all_data = all_data.replace(ordinalEncode)

# %%
all_data.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  LandContour  \
# 0          60         3         65.0     8450       1         0            3
# 1          20         3         80.0     9600       1         0            3
# 2          60         3         68.0    11250       1         1            3
# 3          70         3         60.0     9550       1         1            3
# 4          60         3         84.0    14260       1         1            3
#
#    LotConfig  LandSlope  Neighborhood  Condition1  Condition2  BldgType  \
# 0          4          0             5           2           2         4
# 1          2          0            24           1           2         4
# 2          4          0             5           2           2         4
# 3          0          0             6           2           2         4
# 4          2          0            15           2           2         4
#
#    HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd  RoofStyle  \
# 0           3            7            5       2003          2003          1
# 1           1            6            8       1976          1976          1
# 2           3            7            5       2001          2002          1
# 3           3            7            5       1915          1970          1
# 4           3            8            5       2000          2000          1
#
#    RoofMatl  Exterior1st  Exterior2nd  MasVnrType  MasVnrArea  ExterQual  \
# 0         0           12           13           1       196.0          4
# 1         0            8            8           2         0.0          3
# 2         0           12           13           1       162.0          4
# 3         0           13           15           2         0.0          3
# 4         0           12           13           1       350.0          4
#
#    ExterCond  Foundation  BsmtQual  BsmtCond  BsmtExposure  BsmtFinType1  \
# 0          3           2         4         3             1             6
# 1          3           1         4         3             4             5
# 2          3           2         4         3             2             6
# 3          3           0         3         4             1             5
# 4          3           2         4         3             3             6
#
#    BsmtFinSF1  BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  Heating  \
# 0       706.0             1         0.0      150.0        856.0        1
# 1       978.0             1         0.0      284.0       1262.0        1
# 2       486.0             1         0.0      434.0        920.0        1
# 3       216.0             1         0.0      540.0        756.0        1
# 4       655.0             1         0.0      490.0       1145.0        1
#
#    HeatingQC  CentralAir  Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0          5           1           4       856       854             0
# 1          5           1           4      1262         0             0
# 2          5           1           4       920       866             0
# 3          4           1           4       961       756             0
# 4          5           1           4      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710           1.0           0.0         2         1             3
# 1       1262           0.0           1.0         2         0             3
# 2       1786           1.0           0.0         2         1             3
# 3       1717           1.0           0.0         1         0             3
# 4       2198           1.0           0.0         2         1             4
#
#    KitchenAbvGr  KitchenQual  TotRmsAbvGrd  Functional  Fireplaces  \
# 0             1            4             8           7           0
# 1             1            3             6           7           1
# 2             1            4             6           7           1
# 3             1            4             7           7           1
# 4             1            4             9           7           1
#
#    FireplaceQu  GarageType  GarageYrBlt  GarageFinish  GarageCars  GarageArea  \
# 0            0           1       2003.0             2         2.0       548.0
# 1            3           1       1976.0             2         2.0       460.0
# 2            3           1       2001.0             2         2.0       608.0
# 3            4           5       1998.0             3         3.0       642.0
# 4            3           1       2000.0             2         3.0       836.0
#
#    GarageQual  GarageCond  PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# 0           3           3           1           0           61              0
# 1           3           3           1         298            0              0
# 2           3           3           1           0           42              0
# 3           3           3           1           0           35            272
# 4           3           3           1         192           84              0
#
#    3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  SaleType  \
# 0          0            0         0        0       2    2008         8
# 1          0            0         0        0       5    2007         8
# 2          0            0         0        0       9    2008         8
# 3          0            0         0        0       2    2006         8
# 4          0            0         0        0      12    2008         8
#
#    SaleCondition
# 0              5
# 1              5
# 2              5
# 3              4
# 4              5

# %%
trainset.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
# Correlation matrix 
corr = trainset.corr().abs()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col1 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col2 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col3 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col4 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col5 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col6 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col7 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col8 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col9 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col11 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col12 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col14 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col15 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col16 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col17 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col18 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col19 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col20 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col21 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col22 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col23 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col24 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col25 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col26 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col27 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col28 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col29 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col30 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col31 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col32 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col33 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col34 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col35 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col36 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row0_col37 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row1_col0 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row1_col2 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row1_col3 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row1_col4 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row1_col5 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row1_col6 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row1_col7 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row1_col8 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row1_col9 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row1_col10 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row1_col11 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row1_col12 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row1_col13 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row1_col14 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row1_col15 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row1_col16 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row1_col17 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row1_col18 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row1_col19 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row1_col20 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_1764d178_04e4_11eb_b012_1564c93ad368row1_col21 {
#             background-color:  #

# %% [markdown]
# Based on the correlation matrix above, we see a high correlation between TotalBsmtSF and 1stFlrSF, as well as GrLivArea and TotRmsAbvGrd, GarageCars and GarageArea. There seems to be some multicolinearity in the dataset.

# %%
#corr['SalePrice'].sort_values(ascending=False)
corr[corr['SalePrice'] > 0.4]['SalePrice'].sort_values(ascending=False)
# Out:
# SalePrice       1.000000
# OverallQual     0.800858
# GrLivArea       0.720516
# GarageCars      0.649256
# TotalBsmtSF     0.646584
# GarageArea      0.636964
# 1stFlrSF        0.625235
# FullBath        0.559048
# TotRmsAbvGrd    0.537462
# YearBuilt       0.535279
# YearRemodAdd    0.521428
# GarageYrBlt     0.499230
# MasVnrArea      0.478862
# Fireplaces      0.466765
# Name: SalePrice, dtype: float64

# %% [markdown]
# Since TotalBsmtSF and 1stFlrSF are highly correlated, I will omit 1stFlrSF (TotalBsmtSF has a higher correlation with SalePrice).
# Since GrLivArea and TotRmsAbvGrd are highly correlated, I will omit TotRmsAbvGrd.
# Since GarageCars and GarageArea are highly correlated, I will omit GarageCars.

# %%
# log transform features and target
# discuss different regression techniques: linear regression, tree? 
#trainset.drop("Id", axis = 1, inplace = True)
all_data["BsmtFinType"] = all_data["BsmtFinType1"] + all_data["BsmtFinType2"]
all_data["BsmtFinSF"] = all_data["BsmtFinSF1"] + all_data["BsmtFinSF2"]
remove = ["1stFlrSF", "TotRmsAbvGrd", "GarageCars", "GarageYrBlt",'GarageCond', 'Exterior2nd', "MSSubClass", "Fireplaces",
         "BsmtFinType1", "BsmtFinType2", "BsmtFinSF1", "BsmtFinSF2", "OverallQual", "YearBuilt"]
all_data.drop(remove, axis = 1, inplace = True)

# %%
all_data.columns
# Out:
# Index(['MSZoning', 'LotFrontage', 'LotArea', 'Street', 'LotShape',
#        'LandContour', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
#        'Condition2', 'BldgType', 'HouseStyle', 'OverallCond', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea',
#        'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
#        'KitchenAbvGr', 'KitchenQual', 'Functional', 'FireplaceQu',
#        'GarageType', 'GarageFinish', 'GarageArea', 'GarageQual', 'PavedDrive',
#        'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'BsmtFinType', 'BsmtFinSF'],
#       dtype='object')

# %%
trainset = all_data[:ntrain]
testset = all_data[ntrain:]

# %%
corr = trainset.corr().abs()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col1 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col2 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col3 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col4 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col5 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col6 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col7 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col8 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col9 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col10 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col11 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col12 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col13 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col14 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col15 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col16 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col17 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col18 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col19 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col20 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col21 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col22 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col23 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col24 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col25 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col26 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col27 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col28 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col29 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col30 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col31 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col32 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col33 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col34 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col35 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col36 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col37 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col38 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col39 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col40 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col41 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col42 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col43 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col44 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col45 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col46 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col47 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col48 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col49 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col50 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col51 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col52 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col53 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col54 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col55 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col56 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col57 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col58 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_1ae1043e_04e4_11eb_b012_1564c93ad368row0_col59 {
#             background

# %%
print(trainset.shape, testset.shape)
# Out:
# (1456, 62) (1458, 62)

# %%
# Cursory look at the linear relationship between SalePrice and numeric independent variables 
trainset.head()

fig = plt.figure(figsize = (20,10))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(len(trainset.columns)):
    ax = fig.add_subplot(6, 6, i+1)
    ax.scatter(x = trainset[trainset.columns[i]], y = y_train, marker = '.')
    ax.set_title(f'{trainset.columns[i]}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-6951b1b0133c> in <module>
#       5 fig.subplots_adjust(hspace=0.4, wspace=0.4)
#       6 for i in range(len(trainset.columns)):
# ----> 7     ax = fig.add_subplot(6, 6, i+1)
#       8     ax.scatter(x = trainset[trainset.columns[i]], y = y_train, marker = '.')
#       9     ax.set_title(f'{trainset.columns[i]}')
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1412                     self._axstack.remove(ax)
#    1413
# -> 1414             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1415
#    1416         return self._add_axes_internal(key, a)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      57                 if num < 1 or num > rows*cols:
#      58                     raise ValueError(
# ---> 59                         f"num must be 1 <= num <= {rows*cols}, not {num}")
#      60                 self._subplotspec = GridSpec(
#      61                         rows, cols, figure=self.figure)[int(num) - 1]
#
# ValueError: num must be 1 <= num <= 36, not 37

# %%
print(len(y_train))
trainset.shape

# %%
import sklearn.model_selection as ms
from sklearn.model_selection import train_test_split

trainX, testX, trainY, testY = train_test_split(trainset, y_train, test_size=0.2, random_state=0)

# np.random.seed(1)
# testIdxes = np.random.choice(range(117), size= 35, replace=False)
# trainIdxes = list(set(range(117))-set(testIdxes))
# trainX = trainset.iloc[trainIdxes]
# testX  = trainset.iloc[testIdxes]
# trainY = y_train[trainIdxes]
# testY  = y_train[testIdxes]

# %% [markdown]
# ### Multiple Linear Regression

# %%
from sklearn.linear_model import LinearRegression

lm = LinearRegression()
lm.fit(trainset, y_train)
residuals = y_train - lm.predict(trainset)
plt.hist(residuals)
# Out:
# (array([  1.,   5.,  20., 221., 736., 412.,  45.,   8.,   2.,   6.]),
#  array([-142726.28607515, -112412.93767342,  -82099.5892717 ,
#          -51786.24086997,  -21472.89246824,    8840.45593348,
#           39153.80433521,   69467.15273694,   99780.50113866,
#          130093.84954039,  160407.19794211]),
#  <a list of 10 Patch objects>)

# %%
print('MLR R^2 is equal to %.3f' %lm.score(trainset, y_train))
print('MLR RSS is equal to %.3f' %np.sum((lm.predict(trainset) - y_train) ** 2))
# Out:
# MLR R^2 is equal to 0.887
# MLR RSS is equal to 970354370693.279

# %%
MLR_score = lm.score(testX, testY)
MLR_score
# Out:
# 0.8915146564021809

# %% [markdown]
# ### Penalized Linear Regression

# %%
from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression
ridge = Ridge()
lasso = Lasso()
net   = ElasticNet()

# %% [markdown]
# #### RIDGE

# %%
grid_para_ridge = {
    'alpha': np.linspace(1e-3,200,30)
}
grid_search_ridge = ms.GridSearchCV(ridge, grid_para_ridge, scoring='r2', cv=5, n_jobs=-1)
# %time grid_search_ridge.fit(trainX, trainY)
# Out:
# CPU times: user 306 ms, sys: 83.1 ms, total: 389 ms
# Wall time: 1.25 s
# GridSearchCV(cv=5, error_score=nan,
#              estimator=Ridge(alpha=1.0, copy_X=True, fit_intercept=True,
#                              max_iter=None, normalize=False, random_state=None,
#                              solver='auto', tol=0.001),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'alpha': array([1.00000000e-03, 6.89751724e+00, 1.37940345e+01, 2.06905517e+01,
#        2.75870690e+01, 3.44835862e+01, 4.13801034e+01, 4.82766207e+01,
#        5.51731379e+...
#        8.27592069e+01, 8.96557241e+01, 9.65522414e+01, 1.03448759e+02,
#        1.10345276e+02, 1.17241793e+02, 1.24138310e+02, 1.31034828e+02,
#        1.37931345e+02, 1.44827862e+02, 1.51724379e+02, 1.58620897e+02,
#        1.65517414e+02, 1.72413931e+02, 1.79310448e+02, 1.86206966e+02,
#        1.93103483e+02, 2.00000000e+02])},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='r2', verbose=0)

# %%
print(grid_search_ridge.best_params_)
grid_search_ridge.best_score_
# Out:
# {'alpha': 6.897517241379311}
# 0.8570770748166361

# %%
ridge.set_params(alpha= 6.9)
ridge.fit(trainset, y_train)
ridge.score(trainset, y_train) # train score
# Out:
# 0.8864362120304525

# %%
ridge_score = ridge.score(testX, testY)
ridge_score
# Out:
# 0.891872532823613

# %% [markdown]
# #### LASSO

# %%
grid_para_lasso = {
    'alpha': np.linspace(1e-3,200,30)
}
grid_search_lasso = ms.GridSearchCV(lasso, grid_para_lasso, scoring='r2', cv=5, n_jobs=-1)
# %time grid_search_lasso.fit(trainX, trainY)
# Out:
# CPU times: user 557 ms, sys: 39.1 ms, total: 597 ms
# Wall time: 1.28 s
# /home/annie/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35688854287.89343, tolerance: 676735933.8535998
#   positive)
# GridSearchCV(cv=5, error_score=nan,
#              estimator=Lasso(alpha=1.0, copy_X=True, fit_intercept=True,
#                              max_iter=1000, normalize=False, positive=False,
#                              precompute=False, random_state=None,
#                              selection='cyclic', tol=0.0001, warm_start=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'alpha': array([1.00000000e-03, 6.89751724e+00, 1.37940345e+01, 2.06905517e+01,
#        2.75870690e+01, 3....
#        8.27592069e+01, 8.96557241e+01, 9.65522414e+01, 1.03448759e+02,
#        1.10345276e+02, 1.17241793e+02, 1.24138310e+02, 1.31034828e+02,
#        1.37931345e+02, 1.44827862e+02, 1.51724379e+02, 1.58620897e+02,
#        1.65517414e+02, 1.72413931e+02, 1.79310448e+02, 1.86206966e+02,
#        1.93103483e+02, 2.00000000e+02])},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='r2', verbose=0)

# %%
print(grid_search_lasso.best_params_)
grid_search_lasso.best_score_
# Out:
# {'alpha': 13.79403448275862}
# 0.857072096250419

# %%
lasso.set_params(alpha= 13.8)
lasso.fit(trainset, y_train)
lasso.score(trainset, y_train) # train score
# Out:
# 0.8866094891163006

# %%
lasso_score = lasso.score(testX, testY)
lasso_score
# Out:
# 0.8916884456389738

# %% [markdown]
# ### Elastic Net

# %%
grid_para_elastic = {
    'alpha': np.linspace(1e-2, 10, 40),
    'l1_ratio': np.linspace(0.01, 1, 30)
}
grid_search_elastic = ms.GridSearchCV(net, grid_para_elastic, scoring='r2', cv=5, n_jobs=-1)
# %time grid_search_elastic.fit(trainX, trainY)
# Out:
# CPU times: user 29.1 s, sys: 1.39 s, total: 30.5 s
# Wall time: 2min 44s
# /home/annie/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 336945590215.5819, tolerance: 676735933.8535998
#   positive)
# GridSearchCV(cv=5, error_score=nan,
#              estimator=ElasticNet(alpha=1.0, copy_X=True, fit_intercept=True,
#                                   l1_ratio=0.5, max_iter=1000, normalize=False,
#                                   positive=False, precompute=False,
#                                   random_state=None, selection='cyclic',
#                                   tol=0.0001, warm_start=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'alpha': array([ 0.01      ,  0.26615385,  0.52230769,  0.77846154,  1.03461538,
#         1.29076923...
#        0.18068966, 0.21482759, 0.24896552, 0.28310345, 0.31724138,
#        0.35137931, 0.38551724, 0.41965517, 0.4537931 , 0.48793103,
#        0.52206897, 0.5562069 , 0.59034483, 0.62448276, 0.65862069,
#        0.69275862, 0.72689655, 0.76103448, 0.79517241, 0.82931034,
#        0.86344828, 0.89758621, 0.93172414, 0.96586207, 1.        ])},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='r2', verbose=0)

# %%
print(grid_search_elastic.best_params_)
grid_search_elastic.best_score_
# Out:
# {'alpha': 0.01, 'l1_ratio': 0.7610344827586207}
# 0.8572035666258147

# %%
net.set_params(alpha= 0.01, l1_ratio = 0.7610344827586207)
net.fit(trainset, y_train)
net.score(trainset, y_train) # train score
# Out:
# /home/annie/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 426117306227.62537, tolerance: 855884442.9822603
#   positive)
# 0.8865464506227362

# %%
net_score = net.score(testX, testY)

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
regr = RandomForestRegressor()

# %%
grid_para_forest = {
    'bootstrap': [True],
    'max_depth': range(1, 31),
    'n_estimators': [100, 150, 175]
}
grid_search_forest = ms.GridSearchCV(regr, grid_para_forest, scoring='r2', cv=5, n_jobs=-1)
# %time grid_search_forest.fit(trainX, trainY)
# Out:
# CPU times: user 4.71 s, sys: 165 ms, total: 4.87 s
# Wall time: 3min 11s
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=100, n_jobs=None,
#                                              oob_score=False, random_state=None,
#                                              verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'bootstrap': [True], 'max_depth': range(1, 31),
#                          'n_estimators': [100, 150, 175]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='r2', verbose=0)

# %%
print(grid_search_forest.best_params_)
grid_search_forest.best_score_
# Out:
# {'bootstrap': True, 'max_depth': 16, 'n_estimators': 175}
# 0.860645215743714

# %%
grid_para_forest = {
    'bootstrap': [True],
    'max_depth': range(80, 86),
    'n_estimators': range(90, 150, 10)
}
grid_search_forest = ms.GridSearchCV(regr, grid_para_forest, scoring='r2', cv=5, n_jobs=-1)
# %time grid_search_forest.fit(trainX, trainY)
# Out:
# CPU times: user 2.55 s, sys: 55.9 ms, total: 2.6 s
# Wall time: 1min 20s
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=100, n_jobs=None,
#                                              oob_score=False, random_state=None,
#                                              verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'bootstrap': [True], 'max_depth': range(80, 86),
#                          'n_estimators': range(90, 150, 10)},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='r2', verbose=0)

# %%
print(grid_search_forest.best_params_)
grid_search_forest.best_score_
# Out:
# {'bootstrap': True, 'max_depth': 85, 'n_estimators': 100}
# 0.8616743774584968

# %%
regr.set_params(bootstrap= True, max_depth= 82, n_estimators= 120)
regr.fit(trainset, y_train)
regr.score(trainset, y_train) # train score
# Out:
# 0.9816952211092308

# %%
regr_score = regr.score(testX, testY)

# %% [markdown]
# ### Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbmr = GradientBoostingRegressor()

# %%
# No parameter tuning; regular fitting leads to...
gbmr.fit(trainX,trainY)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
gbmr.score(trainX, trainY)
# Out:
# 0.9658232923943935

# %%
gbmr.score(testX, testY)
# Out:
# 0.9104785877166626

# %%
from sklearn.metrics import r2_score 
n_estimators = 50100
steps = range(100, 50100, 1000)

gbmr.set_params(learning_rate = 1, n_estimators=n_estimators, max_depth=3)
gbmr.fit(trainX, trainY)
gen = gbmr.staged_predict(testX)
r2_rate1 = []
for n in range(n_estimators):
           predicted_targets = next(gen)
           if n not in steps: continue
           r2_rate1.append(r2_score(predicted_targets, testY))

# %%
gbmr.set_params(learning_rate = 0.1)
gbmr.fit(trainX, trainY)
gen = gbmr.staged_predict(testX)
r2_rate01 = []
for n in range(n_estimators):
           predicted_targets = next(gen)
           if n not in steps: continue
           r2_rate01.append(r2_score(predicted_targets, testY))

# %%
gbmr.set_params(learning_rate = 0.01)
gbmr.fit(trainX,trainY)
gen = gbmr.staged_predict(testX)
r2_rate001 = []
for n in range(n_estimators):
           predicted_targets = next(gen)
           if n not in steps: continue
           r2_rate001.append(r2_score(predicted_targets, testY))

# %%
plt.plot(steps, r2_rate1,  label=r'R^2 curve for learning_rate = 1')
plt.plot(steps, r2_rate01, label=r'R^2 curve for learning_rate = 0.1')
plt.plot(steps, r2_rate001, label=r'R^2 curve for learning_rate = 0.01')
plt.legend(loc=4)

# %%
gbmr.set_params(learning_rate = 0.1, max_depth = 5)
    
gbmr.fit(trainX, trainY)
gen = gbmr.staged_predict(testX)
r2_maxdepth5 = []
for n in range(n_estimators):
           predicted_targets = next(gen)
           if n not in steps: continue
           r2_maxdepth5.append(r2_score(predicted_targets, testY))

# %%
gbmr.set_params(learning_rate = 0.1, max_depth = 10)
    
gbmr.fit(trainX, trainY)
gen = gbmr.staged_predict(testX)
r2_maxdepth10 = []
for n in range(n_estimators):
           predicted_targets = next(gen)
           if n not in steps: continue
           r2_maxdepth10.append(r2_score(predicted_targets, testY))

# %%
plt.plot(steps, r2_rate01, label='max_depth = 3')
plt.plot(steps, r2_maxdepth5, label='max_depth = 5')
plt.plot(steps, r2_maxdepth10, label='max_depth = 10')
plt.title('$R^2$ curves with different depths')
plt.legend(loc=4)

# %%
n_estimators = 50100
gbmr.set_params(learning_rate=0.1, max_depth=3, n_estimators=n_estimators)
train_r2 = []
test_r2  = []
steps = range(100,50100,1000)

gbmr.fit(trainX, trainY)
gen_train = gbmr.staged_predict(trainX)
gen_test  = gbmr.staged_predict(testX)

for n in range(n_estimators):
           predicted_train = next(gen_train)
           predicted_test  = next(gen_test)
           if n not in steps: continue
           train_r2.append(r2_score(predicted_train, trainY))
           test_r2.append(r2_score(predicted_test, testY))

# %%
plt.plot(steps, train_r2, label='train set $R^2$')
plt.plot(steps, test_r2, label='test set $R^2$')
plt.legend(loc=7)

# %%
gbmr.set_params(learning_rate=0.1, max_depth=3, n_estimators=10000)
gbmr.fit(trainX, trainY)
gbmr.score(testX, testY)
# Out:
# 0.9177530859515673

# %%
gbmr_score = gbmr.score(testX, testY)

# %% [markdown]
# ### SVR

# %%
from sklearn.svm import SVR

# %%
svr = SVR()
svr.set_params(kernel='rbf')
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
from sklearn.model_selection import GridSearchCV
paramDict = {'C':np.linspace(1,100,20), 'gamma':np.linspace(1e-4, 1e-2, 20)}
grid = GridSearchCV(svr, paramDict, return_train_score = True, scoring='r2', cv=5, n_jobs=-1)
ans_svr  = grid.fit(trainX, trainY)

# %%
ans_svr.best_params_
# Out:
# {'C': 1.0, 'gamma': 0.0001}

# %%
ans_svr.best_score_
# Out:
# -0.04914508025719346

# %%
svr.set_params(kernel='sigmoid')
paramDict = {'C':np.linspace(1,100,20), 'gamma':np.linspace(1e-4, 1e-2, 20)}
grid = GridSearchCV(svr, paramDict, return_train_score = True, scoring='r2', cv=5, n_jobs=-1)
ans_svr  = grid.fit(trainX, trainY)
print(ans_svr.best_params_)
print(ans_svr.best_score_)
# Out:
# {'C': 1.0, 'gamma': 0.0001}
# -0.04914505232992785

# %%
from sklearn.model_selection import GridSearchCV
paramDict = {'C':np.linspace(1,100,20), 'gamma':np.linspace(1e-4, 1e-2, 10), 'kernel':{'linear', 'poly', 'rbf', 'sigmoid'}
grid = GridSearchCV(svr, paramDict, return_train_score = True, scoring='r2', cv=5, n_jobs=-1)
ans_svr  = grid.fit(trainX, trainY)

# %%
svr_best = ans_svr.best_estimator_
svr_best.fit(trainX, trainY)
svr_score = svr_best.score(testX, testY)

# %% [markdown]
# ### Model Comparisons

# %%
import matplotlib.pyplot as plt
# fig = plt.figure()
# ax = fig.add_axes([0,0,1,1])
model = ['MLR', 'Ridge', 'Lasso', 'Net', 'RF', 'GB', 'SVR']
scores = [MLR_score,ridge_score, lasso_score, net_score, regr_score, gbmr_score, svr_score]
scoreDF = pd.DataFrame(list(zip(model, scores)), columns = ['model', 'test score'])
print(scoreDF)
#scoreDF.sort_values(by = 'test score', ascending = False).plot.bar(x='model')
plt.barh(model, scores)
for index, value in enumerate(scoreDF['test score']):
    plt.text(value, index, str(round(value,4)))
# Out:
#    model  test score
# 0    MLR    0.891515
# 1  Ridge    0.891873
# 2  Lasso    0.891688
# 3    Net    0.891803
# 4     RF    0.985507
# 5     GB    0.917753
# 6    SVR   -0.077006

# %% [markdown]
# #### Interpret data using our best model, Random Forest

# %%
tree_final = grid_search_forest.best_estimator_
feature_importance = list(zip(trainset.columns[1:], tree_final.feature_importances_))
dtype = [('feature', 'S10'), ('importance', 'float')]
feature_importance = np.array(feature_importance, dtype = dtype)
feature_sort = np.sort(feature_importance, order='importance')[::-1]
feature_sort
# Out:
# array([(b'ExterCond', 3.26253006e-01), (b'BsmtFullBa', 2.04764965e-01),
#        (b'GarageQual', 1.40309394e-01), (b'Heating', 8.11213589e-02),
#        (b'BsmtCond', 2.52444198e-02), (b'Functional', 2.17904626e-02),
#        (b'Street', 1.68142240e-02), (b'LowQualFin', 1.43838624e-02),
#        (b'RoofStyle', 1.29863443e-02), (b'ExterQual', 1.29675508e-02),
#        (b'TotalBsmtS', 8.08791269e-03), (b'LotArea', 7.94296588e-03),
#        (b'BsmtFinSF', 7.03220634e-03), (b'YearRemodA', 6.88198491e-03),
#        (b'OpenPorchS', 6.04179893e-03), (b'GarageType', 5.93579971e-03),
#        (b'Electrical', 5.74745705e-03), (b'Condition1', 5.69720303e-03),
#        (b'EnclosedPo', 4.58025299e-03), (b'GarageFini', 4.43852305e-03),
#        (b'MasVnrType', 4.40247278e-03), (b'BsmtUnfSF', 3.93540227e-03),
#        (b'GarageArea', 3.57887695e-03), (b'HalfBath', 3.23854544e-03),
#        (b'YrSold', 3.11767372e-03), (b'LotFrontag', 3.11531577e-03),
#        (b'KitchenAbv', 2.67457464e-03), (b'BedroomAbv', 2.34472558e-03),
#        (b'SaleType', 2.29709457e-03), (b'PavedDrive', 2.12736031e-03),
#        (b'RoofMatl', 1.92200418e-03), (b'LandContou', 1.81836257e-03),
#        (b'3SsnPorch', 1.52656393e-03), (b'BsmtFinTyp', 1.41420868e-03),
#        (b'CentralAir', 1.27899008e-03), (b'Condition2', 1.02892804e-03),
#        (b'PoolArea', 9.58364928e-04), (b'BsmtExposu', 9.35859498e-04),
#        (b'SaleCondit', 9.07523321e-04), (b'BsmtQual', 9.00321093e-04),
#        (b'FireplaceQ', 9.00019059e-04), (b'LandSlope', 8.61933925e-04),
#        (b'OverallCon', 8.46193423e-04), (b'BsmtHalfBa', 7.57572346e-04),
#        (b'KitchenQua', 6.58826816e-04), (b'MasVnrArea', 6.22452615e-04),
#        (b'Foundation', 5.61583513e-04), (b'Neighborho', 5.58715151e-04),
#        (b'ScreenPorc', 5.54893406e-04), (b'WoodDeckSF', 5.26918129e-04),
#        (b'LotConfig', 4.93930074e-04), (b'HouseStyle', 4.69103363e-04),
#        (b'GrLivArea', 3.90059355e-04), (b'Exterior1s', 3.38092063e-04),
#        (b'HeatingQC', 2.81296660e-04), (b'2ndFlrSF', 2.78448706e-04),
#        (b'FullBath', 2.41008520e-04), (b'MoSold', 1.18558869e-04),
#        (b'MiscVal', 8.88375892e-05), (b'BldgType', 4.54061127e-05),
#        (b'LotShape', 1.56458029e-05)],
#       dtype=[('feature', 'S10'), ('importance', '<f8')])

# %%
top20 = sorted(feature_sort, key=lambda t: t[1], reverse=True)[:20]

# %%
featureNames, featureScores = zip(*list(top20))
plt.barh(range(len(featureScores)), featureScores, tick_label=featureNames)
# Out:
# <BarContainer object of 20 artists>

# %%
from graphviz import Source
from sklearn import tree
from IPython.display import SVG
treeIdx = 10 # has to be less than 60
myTreeModel = grid_search_forest.best_estimator_.estimators_[treeIdx]

graph = Source(tree.export_graphviz(myTreeModel, out_file=None, feature_names=trainset.columns))
#SVG(graph.pipe(format='svg'))
graph.format = 'png'
graph.render('dtree_render',view=True)
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.621895 to fit
# 'dtree_render.png'
